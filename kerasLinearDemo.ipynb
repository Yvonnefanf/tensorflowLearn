# %%
import pandas as pd
data = pd.read_csv('./data/income.csv')
data
# Out:
#     Education  Income
# 0       10.00   26.66
# 1       10.40   27.31
# 2       10.84   22.13
# 3       11.24   21.17
# 4       11.65   15.19
# 5       12.09   26.40
# 6       12.89   25.51
# 7       13.29   36.88
# 8       13.73   39.67
# 9       14.13   34.40
# 10      14.54   41.50
# 11      14.98   44.98
# 12      15.38   47.04
# 13      15.78   48.25
# 14      16.22   57.03
# 15      16.62   51.49
# 16      17.02   61.34
# 17      17.46   57.58
# 18      17.87   68.55
# 19      18.26   64.31
# 20      18.71   68.96
# 21      19.11   74.61
# 22      19.51   71.87
# 23      19.91   71.87
# 24      20.35   75.78
# 25      20.76   72.49
# 26      21.16   77.36
# 27      21.60   72.12
# 28      22.00   80.26

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(data.Education, data.Income)

# %%
x = data.Education
y = data.Income

# %%
model. =tf.keras.Sequential()
# Out:
#   File "/var/folders/k1/0swzs7zs7_155rr2qpbgv3440000gn/T/ipykernel_28698/286791128.py", line 1
#     model. =tf.keras.Sequential()
#            ^
# SyntaxError: invalid syntax
